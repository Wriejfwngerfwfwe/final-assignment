# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkST0151ENSkillsNetwork20531532-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# #### Import the required libraries we need for the lab.

# %%
import piplite
await piplite.install(['numpy'],['pandas'])
await piplite.install(['seaborn'])

# %%
import pandas as pd
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %% [markdown]
# #### Read the dataset in the csv file from the URL

# %%
from js import fetch
import io

URL = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ST0151EN-SkillsNetwork/labs/boston_housing.csv'
resp = await fetch(URL)
boston_url = io.BytesIO((await resp.arrayBuffer()).to_py())

# %%
boston_df=pd.read_csv(boston_url)

# %% [markdown]
# #### Add your code below following the instructions given in the course to complete the peer graded assignment

# %%
ax = sns.boxplot(x='MEDV', data=boston_df) #graoh for boxplot with the Bosotn Data
plt.title("Median value of owner-occupied homes") # title for the boxplot
plt.xlabel('MEDV in $1000s')
plt.show() # Display the results that was given from the Boston Data

# %% [markdown]
# The boxplot shows the median value for the MEDV that is among with the outliers.

# %%
x1 = sns.catplot(x='CHAS', kind='count', data=boston_df) # Setup a bar chart from the Boston Data
plt.title('Bar Chart: Frequency Distribution of Charles River Dummy Variable (1 for Tracts Bordering, 0 Otherwis') # Give a title to the chart
plt.xlabel('CHAS') # Set the x-label to Charles Rivr Dummy Variable
plt.ylabel('Frequency') # Set the frequency in the y-label
plt.show() #Display the catplot chart

# %% [markdown]
# The histogram shows tjhe amjority for the houses that are not close to the Charles River.

# %%
boston_df.loc[(boston_df['AGE'] <= 35), 'age_group'] = '35 years and younger' # Setup the different age groups with the Boston Data
boston_df.loc[(boston_df['AGE'] > 35) & (boston_df['AGE'] < 70), 'age_group'] = 'between 35 and 70 years'
boston_df.loc[(boston_df['AGE'] >= 70), 'age_group'] = '70 years and older'

# %%
ax = sns.boxplot(x='age_group', y= 'MEDV', data=boston_df) # Create a box plot for the age group and the median value of owner-occupied homes in the $1000s
plt.title('MEDV based on age groups') # Give a title to the chart
plt.xlabel('Age groups')
plt.ylabel('Median value of owner-occupied homes (MEDV)')
plt.show() # Display the boxplot with the age groups and the median value

# %% [markdown]
# The boxplot shows the average the median value for the owner occupies homes is higher when the age is lower.

# %% [markdown]
# Null Hypothesis: There is no relationship between  Nitric oxide concentrations and proportion of non-retail business acres per town.

# %% [markdown]
# Alternate Hypothesis: There is no relationship between  Nitric oxide concentrations and proportion of non-retail business acres per town.

# %%
ax = sns.scatterplot(x='NOX', y='INDUS', data=boston_df) # Setup a scatter plot for the Boston Data with non-retail and nitric oxides concentration
plt.title('Scatter Plot: Relationship between NOX and INDUS') # Setup a title for the scatter plot
plt.xlabel('Nitric oxides concentration parts per 10 million (NOX)') 
plt.ylabel('Proportion of non-retail business acres per town (INDUS)')
plt.show() # Display the scatter plot with x and y labels.

# %% [markdown]
# The values that are located on the bottom of the scatter plot indicates that there is a strong relation that is between low Nitric oxide concentration and low proportion for non-retail business acres per town.

# %% [markdown]
# There is a higher proprtion for non-retail business acres per town produes higher conentration of Nitric Oxide.

# %%
scipy.stats.pearsonr(boston_df['NOX'], boston_df['INDUS']) # Calculate a Pearson correlation coefficient and the p-value for testing non-correlation
# Out:
# PearsonRResult(statistic=0.7636514469209151, pvalue=7.913361061239527e-98)

# %% [markdown]
# Given that 0.7913 is less than 0.05, we can reject the Null Hypothesis as there is a postive correlation between the Nitric oxide concentrations and proportion of non-retail business acres per town.

# %%
plt.hist(boston_df['PTRATIO']) # Create a histogram for pupil-teacher ration by town
plt.xlabel('The pupil to teacher ratio (PTRATIO)') # Create a title
plt.ylabel('Number of observations')
plt.title("Histogram for the pupil to teacher ratio variable (PTRATIO)")
plt.show() # Display the histogram for the x and y labels

# %%
ax5 = sns.countplot(x = 'PTRATIO', data = boston_df)
ax5.set_title('Pupil to teacher ratio per town')
# Out:
# Text(0.5, 1.0, 'Pupil to teacher ratio per town')

# %%
	
boston_df.loc[(boston_df['CHAS'] == 0), 'CHAS_T'] = 'FAR'
boston_df.loc[(boston_df['CHAS'] == 1), 'CHAS_T'] = 'NEAR'
boston_df.head(5)
# Out:
#    Unnamed: 0     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  \
# 0           0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0
# 1           1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0
# 2           2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0
# 3           3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0
# 4           4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0
#
#      TAX  PTRATIO  LSTAT  MEDV CHAS_T
# 0  296.0     15.3   4.98  24.0    FAR
# 1  242.0     17.8   9.14  21.6    FAR
# 2  242.0     17.8   4.03  34.7    FAR
# 3  222.0     18.7   2.94  33.4    FAR
# 4  222.0     18.7   5.33  36.2    FAR

# %% [markdown]
# Null Hypothesis: There is no significant difference in between the median value between houses bounded and not bounded by the Charles River.

# %% [markdown]
# Alternate Hypothesis: There is a significant difference in between the median value between houses bounded and not bounded by the Charles River.

# %% [markdown]
# Since the P-value is less thwan 0.5 as this can allow use to reject the Null Hypothesis in showing that there is no statistical different in the
# median value that are between the houses near the Charles River and houses that are far away.

# %%
from statsmodels.formula.api import ols
lm = ols('MEDV ~ AGE', data = boston_df).fit()
table = sm.stats.anova_lm(lm)
print(table)
# Out:
#              df        sum_sq      mean_sq          F        PR(>F)
# AGE         1.0   6069.761065  6069.761065  83.477459  1.569982e-18
# Residual  504.0  36646.534350    72.711378        NaN           NaN

# %% [markdown]
# Since the P-value is less than 0.5 as we can regret the Nully Hypothesis and says that there is no statistical difference in Median values of houses (MEDV) for each proportion of owner occpied units built prior to 1940.

# %% [markdown]
# Null Hypothesis: There is no statisiscal difference in Median values of houses for each proortion of owner occupied in the units built prior to 1949.

# %% [markdown]
# Alternate Hypothesis: There is statistical difference in Median values of houses (MEDV) for each proportion of owner occpied units built prior to 1940.

# %%
scipy.stats.levene(boston_df[boston_df['CHAS'] == 0]['MEDV'], boston_df[boston_df['CHAS'] == 1]['MEDV'], center='median') # since the data is skewed, we use median as center and it is greater than alpha value 0.05,
# Do a levene test against the Charles River Dummy variable and the median value of owner-occupied homes in the $1000s to find the median
# Out:
# LeveneResult(statistic=4.590342218715871, pvalue=0.03263097600633006)

# %%
scipy.stats.ttest_ind(boston_df[boston_df['CHAS'] == 0]['MEDV'], boston_df[boston_df['CHAS'] == 1]['MEDV'], equal_var=True) # since p-value is less than alpha value 0.05, we reject the null hypothesis,
# Out:
# TtestResult(statistic=-3.996437466090509, pvalue=7.390623170519905e-05, df=504.0)

# %%
x = boston_df['DIS']
y = boston_df['MEDV']
x = sm.add_constant(x)
model = sm.OLS(y, x).fit()
prediction = model.predict(x)
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   MEDV   R-squared:                       0.062
# Model:                            OLS   Adj. R-squared:                  0.061
# Method:                 Least Squares   F-statistic:                     33.58
# Date:                Fri, 12 Apr 2024   Prob (F-statistic):           1.21e-08
# Time:                        12:39:30   Log-Likelihood:                -1823.9
# No. Observations:                 506   AIC:                             3652.
# Df Residuals:                     504   BIC:                             3660.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         18.3901      0.817     22.499      0.000      16.784      19.996
# DIS            1.0916      0.188      5.795      0.000       0.722       1.462
# ==============================================================================
# Omnibus:                      139.779   Durbin-Watson:                   0.570
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              305.104
# Skew:                           1.466   Prob(JB):                     5.59e-67
# Kurtosis:                       5.424   Cond. No.                         9.32
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# The coefficient for DIS is 1.0916 as this indicates that additional weight distance to the 5 employment centers in Bsoton increases to be 1.0916 with the median value for the owner occupied homes.
